# %%
import pandas as pd

# %%
# Series without index access, default 0, 1 etc
data = [1,2,3,4,5]
df = pd.Series(data)
df[0]
# Out:
# 1

# %%
# Series index access
data = [1,2,3,4,5,6]
df = pd.Series(data, index=['a','b','c','d','e','f'])
df['a']
# Out:
# 1

# %%
# Series with dict, keys will become indexes
data = {"a": 1, "b":2, "c":3, "d":4}
df = pd.Series(data)
df
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
# Series we can mention some items based on index
data = {"a": 1, "b":2, "c":3, "d":4}
df = pd.Series(data, index=["a", "b"])
df
# Out:
# a    1
# b    2
# dtype: int64

# %%
# Dataframe with dict, keys will become lables
data = {
    "a": [1,2,3,4,5],
    "b": [11,22,33,44,55]
}
df = pd.DataFrame(data)
df
# Out:
#    a   b
# 0  1  11
# 1  2  22
# 2  3  33
# 3  4  44
# 4  5  55

# %%
# Dataframe with loc to get record
data = {
    "a": [1,2,3,4,5],
    "b": [11,22,33,44,55]
}
df = pd.DataFrame(data, index = ["i1", "i2", "i3", "i4", "i5"])
#df.loc[0]
# df.loc[[0,2]]
df.loc['i4']
# Out:
# a     4
# b    44
# Name: i4, dtype: int64

# %%
df = pd.read_json('data.json')
pd.options.display.max_rows = 100

# %%
# fill for only one column
df['Calories'].fillna(1000, inplace=True)
df[10:20]
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 10        60    103       147     329.3
# 11        60    100       120     250.7
# 12        60    106       128     345.3
# 13        60    104       132     379.3
# 14        60     98       123     275.0
# 15        60     98       120     215.2
# 16        60    100       120     300.0
# 17        45     90       112    1000.0
# 18        60    103       123     323.0
# 19        45     97       125     243.0

# %%
# fill for only one column
df.fillna(1000, inplace=True)
df[20:30]
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 20        60    108       131     364.2
# 21        45    100       119     282.0
# 22        60    130       101     300.0
# 23        45    105       132     246.0
# 24        60    102       126     334.5
# 25        60    100       120     250.0
# 26        60     92       118     241.0
# 27        60    103       132    1000.0
# 28        60    100       132     280.0
# 29        60    102       129     380.3

# %%
df.dropna()
df.shape
# Out:
# (169, 4)

# %%
pd.options.display.max_rows = 6

# %%
df = pd.read_csv("earthquakes.csv")

# %%
df
# Out:
#      alert  cdi        code  \
# 0      NaN  NaN    37389218
# 1      NaN  NaN    37389202
# 2      NaN  4.4    37389194
# ...    ...  ...         ...
# 9329   NaN  NaN  2018261000
# 9330   NaN  NaN    38063959
# 9331   NaN  NaN    38063935
#
#                                                  detail      dmin  felt  \
# 0     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.008693   NaN
# 1     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.020030   NaN
# 2     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.021370  28.0
# ...                                                 ...       ...   ...
# 9329  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.452600   NaN
# 9330  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.018650   NaN
# 9331  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.016980   NaN
#
#         gap             ids   mag magType  ...  sources     status  \
# 0      85.0    ,ci37389218,  1.35      ml  ...     ,ci,  automatic
# ...

# %%
pd.__version__
# Out:
# '2.0.3'

# %%
df
# Out:
#      alert  cdi        code  \
# 0      NaN  NaN    37389218
# 1      NaN  NaN    37389202
# 2      NaN  4.4    37389194
# 3      NaN  NaN    37389186
# 4      NaN  NaN    73096941
# ...    ...  ...         ...
# 9327   NaN  NaN    73086771
# 9328   NaN  NaN    38063967
# 9329   NaN  NaN  2018261000
# 9330   NaN  NaN    38063959
# 9331   NaN  NaN    38063935
#
#                                                  detail      dmin  felt  \
# 0     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.008693   NaN
# 1     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.020030   NaN
# 2     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.021370  28.0
# 3     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.026180   NaN
# 4     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.077990   NaN
# ...                                                 ...       ...   ...
# 9327  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.018060   NaN
# ...

# %%
df
# Out:
#    a   b
# 0  1  11
# 1  2  22
# 2  3  33
# 3  4  44
# 4  5  55
